# %%
import os

# Separate lists to store extracted data as integers
n_values = []
m_values = []
width_values = []
time_values = []
nbags_values = []

import csv

# Read data from CSV file
with open('output.csv', mode='r') as file:
    csv_reader = csv.reader(file)
    
    # Skip the header row
    next(csv_reader)

    # Process each row in the CSV
    for row in csv_reader:
        n_values.append(int(row[1]))         # Num Vertices
        m_values.append(int(row[2]))            # Num Edges
        width_values.append(int(row[3]))             # Treewidth
        nbags_values.append(int(row[4]))                  # Bags
        time_values.append(int(row[5]))        # Execution Time (milliseconds)

# Displaying the lists
print("Num Vertices:", n_values)
print("Num Edges:", m_values)
print("Treewidth:", width_values)
print("Bags:", nbags_values)
print("Execution Time (milliseconds):", time_values)
# Out:
# Num Vertices: [714, 2113, 817, 167, 82, 836, 751, 81, 56, 193, 762, 102, 112, 735, 900, 604, 64, 378, 340, 100, 307, 121, 926, 7, 1643, 90, 125, 179, 50, 1996, 849, 42, 85, 111, 303, 196, 100, 172, 68, 144, 2835, 661, 96, 95, 1847, 1684, 1751, 630, 603, 100, 299, 1003, 708, 13, 452, 56, 1675, 49, 85, 742, 332, 1692, 172, 916, 363, 1558, 120, 739, 51, 786, 840, 199, 192, 1149, 921, 56, 676, 1545, 125, 1069, 81, 100, 112, 790, 614, 717, 112, 239, 126, 1910, 1692, 773, 121, 125, 1848, 725, 1024, 988, 2030]
# Num Edges: [1334, 4373, 1522, 391, 146, 1436, 1948, 810, 280, 642, 1472, 153, 336, 1479, 1795, 1128, 224, 993, 1425, 1800, 4403, 1265, 1771, 9, 3291, 135, 736, 2428, 175, 4007, 1503, 126, 850, 199, 524, 4596, 475, 408, 408, 1750, 7638, 1283, 1261, 505, 3752, 3210, 3501, 1223, 1213, 1100, 4053, 1704, 3714, 22, 806, 280, 3425, 476, 850, 1419, 580, 3354, 408, 1644, 2992, 2898, 240, 1451, 240, 1455, 1714, 842, 1230, 2044, 1614, 756, 1348, 2922, 6961, 1785, 968, 269, 168, 1523, 1187, 1400, 168, 2932, 189, 3854, 3275, 1419, 3630, 6961, 3574, 1397, 1797, 1845, 4215]
# Treewidth: [38, 138, 44, 10, 5, 27, 49, 54, 34, 27, 40, 24, 42, 58, 77, 29, 33, 24, 96, 87, 55, 54, 49, 2, 110, 20, 66, 42, 28, 151, 35, 23, 64, 7, 11, 79, 36, 10, 44, 73, 89, 45, 68, 34, 112, 95, 90, 32, 34, 77, 46, 42, 51, 3, 18, 36, 117, 37, 64, 44, 15, 91, 11, 40, 163, 81, 29, 42, 11, 36, 64, 56, 58, 50, 34, 44, 42, 92, 119, 33, 57, 25, 27, 59, 40, 43, 27, 32, 30, 113, 88, 53, 109, 119, 126, 52, 52, 58, 140]
# Bags: [676, 1975, 773, 157, 77, 809, 702, 27, 22, 166, 722, 78, 70, 677, 823, 575, 31, 354, 244, 13, 252, 67, 877, 5, 1533, 70, 59, 139, 22, 1845, 814, 19, 21, 105, 292, 137, 64, 162, 24, 71, 2746, 616, 28, 61, 1735, 1589, 1661, 598, 569, 23, 256, 961, 660, 10, 434, 23, 1558, 13, 21, 698, 317, 1601, 161, 876, 200, 1477, 93, 697, 40, 750, 776, 143, 142, 1099, 887, 12, 634, 1453, 7, 1036, 29, 75, 85, 731, 574, 674, 85, 212, 96, 1797, 1604, 720, 12, 7, 1722, 673, 972, 930, 1890]
# Execution Time (milliseconds): [1064, 13367, 652, 17, 6, 520, 841, 121, 12, 83, 572, 17, 35, 693, 3615, 351, 14, 175, 805, 157, 154, 71, 728, 2, 4939, 17, 209, 252, 54, 9133, 726, 11, 56, 7, 33, 379, 40, 14, 26, 171, 27659, 649, 96, 53, 8945, 5600, 7937, 726, 649, 129, 643, 745, 2028, 11, 254, 41, 7261, 23, 90, 1091, 70, 5955, 26, 1174, 5735, 5147, 66, 1518, 9, 730, 1361, 223, 16131, 1468, 1084, 45, 828, 3771, 103, 758, 99, 30, 34, 1010, 449, 683, 22, 134, 39, 8324, 5153, 1030, 504, 252, 7838, 697, 1029, 1343, 16355]

# %%
import numpy as np
import matplotlib.pyplot as plt

# Combine n_values and width_values into a single array for sorting
combined = list(zip(n_values, width_values))

# Sort the combined list based on n_values
sorted_combined = sorted(combined)

# Unzip the sorted list back into two separate lists
sorted_n_values, sorted_width_values = zip(*sorted_combined)

# Create the plot
plt.figure(figsize=(10, 6))
plt.plot(sorted_n_values, sorted_width_values, marker='o', linestyle='-')
plt.xlabel('Node')
plt.ylabel('Width')
plt.grid(True)
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt

# Combine n_values and width_values into a single array for sorting
combined = list(zip(m_values, width_values))

# Sort the combined list based on n_values
sorted_combined = sorted(combined)

# Unzip the sorted list back into two separate lists
sorted_n_values, sorted_width_values = zip(*sorted_combined)

# Create the plot
plt.figure(figsize=(10, 6))
plt.plot(sorted_n_values, sorted_width_values, marker='o', linestyle='-')
plt.xlabel('Edge')
plt.ylabel('Width')
plt.grid(True)
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt

# Combine n_values and width_values into a single array for sorting
combined = list(zip(n_values, time_values))

# Sort the combined list based on n_values
sorted_combined = sorted(combined)

# Unzip the sorted list back into two separate lists
sorted_n_values, sorted_width_values = zip(*sorted_combined)

# Create the plot
plt.figure(figsize=(10, 6))
plt.plot(sorted_n_values, sorted_width_values, marker='o', linestyle='-')
plt.xlabel('Node')
plt.ylabel('Time')
plt.grid(True)
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt

# Combine n_values and width_values into a single array for sorting
combined = list(zip(m_values, time_values))

# Sort the combined list based on n_values
sorted_combined = sorted(combined)

# Unzip the sorted list back into two separate lists
sorted_n_values, sorted_width_values = zip(*sorted_combined)

# Create the plot
plt.figure(figsize=(10, 6))
plt.plot(sorted_n_values, sorted_width_values, marker='o', linestyle='-')
plt.xlabel('Edge')
plt.ylabel('Time')
plt.grid(True)
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt

# Combine n_values and width_values into a single array for sorting
combined = list(zip(n_values, nbags_values))

# Sort the combined list based on n_values
sorted_combined = sorted(combined)

# Unzip the sorted list back into two separate lists
sorted_n_values, sorted_width_values = zip(*sorted_combined)

# Create the plot
plt.figure(figsize=(10, 6))
plt.plot(sorted_n_values, sorted_width_values, marker='o', linestyle='-')
plt.xlabel('Node')
plt.ylabel('Bags')
plt.grid(True)
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt

# Combine n_values and width_values into a single array for sorting
combined = list(zip(m_values, nbags_values))

# Sort the combined list based on n_values
sorted_combined = sorted(combined)

# Unzip the sorted list back into two separate lists
sorted_n_values, sorted_width_values = zip(*sorted_combined)

# Create the plot
plt.figure(figsize=(10, 6))
plt.plot(sorted_n_values, sorted_width_values, marker='o', linestyle='-')
plt.xlabel('Edge')
plt.ylabel('Bags')
plt.grid(True)
plt.show()
