# %%
import os
import matplotlib.pyplot as plt
import seaborn as sns
import glob
import csv

output_files = sorted(glob.glob('./output/*.twc'))
print(len(output_files))
# Out:
# 77

# %%
import os

# Separate lists to store extracted data as integers
n_values = []
m_values = []
width_values = []
time_values = []
nbags_values = []

# Specify the directory containing the .twc files
output_directory = 'output'

# Iterate through each file in the output directory
for filename in os.listdir(output_directory):
    if filename.endswith('.twc'):  # Process only .twc files
        file_path = os.path.join(output_directory, filename)  # Create full path to the file
        with open(file_path, 'r') as file:
            lines = file.readlines()
            if len(lines) >= 4:  # Ensure there are at least 4 lines
                # Extracting values using string manipulation
                first_line = lines[0]
                width_time_line = lines[2]
                nbags_line = lines[3]

                # Extracting n and m from the first line
                n_value = int(first_line.split('n ')[1].split(' ')[0])  # Convert to integer
                m_value = int(first_line.split('m ')[1].split(' ')[0])  # Convert to integer

                # Extracting width and time from the third line
                width_value = int(width_time_line.split('width ')[1].split(' ')[0])  # Convert to integer
                time_value = int(width_time_line.split('time(ms) ')[1].strip())  # Convert to integer

                # Extracting nbags from the fourth line
                nbags_value = int(nbags_line.split('nbags ')[1].strip())  # Convert to integer

                # Append extracted values to their respective lists
                n_values.append(n_value)
                m_values.append(m_value)
                width_values.append(width_value)
                time_values.append(time_value)  # Cleaned time values
                nbags_values.append(nbags_value)

# Print the extracted data lists
print("N values:", n_values)
print("M values:", m_values)
print("Width values:", width_values)
print("Time values:", time_values)  # Cleaned time values
print("Nbags values:", nbags_values)
# Out:
# N values: [285, 170, 136, 237, 213, 257, 256, 111, 363, 235, 249, 92, 176, 262, 365, 377, 370, 48, 454, 117, 198, 71, 318, 116, 140, 137, 218, 266, 205, 207, 404, 235, 278, 66, 99, 589, 177, 272, 220, 201, 136, 106, 616, 247, 298, 243, 219, 244, 229, 600, 291, 170, 238, 102, 221, 238, 158, 251, 330, 329, 342, 152, 119, 193, 197, 712, 466, 275, 116, 279, 193, 253, 318, 115, 465, 188, 285]
# M values: [526, 415, 254, 423, 380, 453, 465, 360, 541, 441, 434, 472, 308, 648, 878, 597, 561, 96, 664, 332, 352, 925, 572, 522, 336, 451, 383, 460, 341, 368, 607, 424, 522, 838, 549, 825, 669, 615, 555, 365, 471, 558, 923, 804, 780, 428, 382, 717, 370, 865, 752, 396, 1077, 446, 383, 411, 1058, 430, 571, 573, 588, 492, 415, 860, 813, 1085, 662, 438, 522, 513, 336, 434, 576, 354, 1004, 638, 735]
# Width values: [9, 12, 10, 10, 10, 11, 9, 8, 7, 9, 10, 20, 9, 10, 12, 7, 7, 8, 7, 13, 9, 26, 9, 16, 11, 12, 9, 9, 9, 9, 7, 10, 9, 28, 18, 7, 15, 10, 11, 11, 15, 20, 7, 14, 10, 9, 8, 9, 8, 7, 11, 10, 15, 17, 9, 9, 22, 9, 9, 9, 9, 10, 9, 16, 18, 7, 7, 8, 16, 9, 9, 9, 9, 8, 9, 6, 11]
# Time values: [2037, 5635, 2207, 9296, 6863, 4341, 187975, 2550, 2955, 2972, 4565, 34431, 2023, 13358, 5047, 35953, 3034, 2708, 16017, 1635, 5948, 322, 2437, 4563, 1718, 1419, 2033, 16034, 6585, 5796, 4810, 2011, 1930, 610, 1995, 2738, 2672, 7702, 19655, 2984, 9307, 7532, 31141, 22759, 3128, 1466, 29524, 1390, 14733, 4423, 112174, 5395, 2488, 3867, 5257, 1900, 209303, 2292, 3247, 26177, 48729, 5869, 2102, 4738, 2112, 6988, 15656, 9387, 4398, 7097, 19265, 10074, 29663, 1506, 3510, 3623, 253525]
# Nbags values: [229, 129, 101, 179, 169, 227, 212, 97, 333, 207, 192, 49, 141, 188, 203, 340, 333, 40, 414, 96, 165, 29, 253, 76, 103, 103, 168, 203, 164, 167, 366, 193, 223, 32, 61, 540, 123, 190, 154, 176, 103, 56, 570, 196, 249, 205, 195, 159, 210, 548, 236, 133, 101, 68, 175, 190, 116, 193, 273, 258, 265, 130, 83, 131, 102, 640, 433, 251, 76, 228, 175, 190, 267, 103, 384, 135, 223]

# %%
import numpy as np
import matplotlib.pyplot as plt

# Combine n_values and width_values into a single array for sorting
combined = list(zip(n_values, width_values))

# Sort the combined list based on n_values
sorted_combined = sorted(combined)

# Unzip the sorted list back into two separate lists
sorted_n_values, sorted_width_values = zip(*sorted_combined)

# Create the plot
plt.figure(figsize=(10, 6))
plt.plot(sorted_n_values, sorted_width_values, marker='o', linestyle='-')
plt.xlabel('Node')
plt.ylabel('Width')
plt.grid(True)
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt

# Combine n_values and width_values into a single array for sorting
combined = list(zip(m_values, width_values))

# Sort the combined list based on n_values
sorted_combined = sorted(combined)

# Unzip the sorted list back into two separate lists
sorted_n_values, sorted_width_values = zip(*sorted_combined)

# Create the plot
plt.figure(figsize=(10, 6))
plt.plot(sorted_n_values, sorted_width_values, marker='o', linestyle='-')
plt.xlabel('Edge')
plt.ylabel('Width')
plt.grid(True)
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt

# Combine n_values and width_values into a single array for sorting
combined = list(zip(n_values, time_values))

# Sort the combined list based on n_values
sorted_combined = sorted(combined)

# Unzip the sorted list back into two separate lists
sorted_n_values, sorted_width_values = zip(*sorted_combined)

# Create the plot
plt.figure(figsize=(10, 6))
plt.plot(sorted_n_values, sorted_width_values, marker='o', linestyle='-')
plt.xlabel('Node')
plt.ylabel('Time')
plt.grid(True)
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt

# Combine n_values and width_values into a single array for sorting
combined = list(zip(m_values, time_values))

# Sort the combined list based on n_values
sorted_combined = sorted(combined)

# Unzip the sorted list back into two separate lists
sorted_n_values, sorted_width_values = zip(*sorted_combined)

# Create the plot
plt.figure(figsize=(10, 6))
plt.plot(sorted_n_values, sorted_width_values, marker='o', linestyle='-')
plt.xlabel('Edge')
plt.ylabel('Time')
plt.grid(True)
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt

# Combine n_values and width_values into a single array for sorting
combined = list(zip(n_values, nbags_values))

# Sort the combined list based on n_values
sorted_combined = sorted(combined)

# Unzip the sorted list back into two separate lists
sorted_n_values, sorted_width_values = zip(*sorted_combined)

# Create the plot
plt.figure(figsize=(10, 6))
plt.plot(sorted_n_values, sorted_width_values, marker='o', linestyle='-')
plt.xlabel('Node')
plt.ylabel('Bags')
plt.grid(True)
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt

# Combine n_values and width_values into a single array for sorting
combined = list(zip(m_values, nbags_values))

# Sort the combined list based on n_values
sorted_combined = sorted(combined)

# Unzip the sorted list back into two separate lists
sorted_n_values, sorted_width_values = zip(*sorted_combined)

# Create the plot
plt.figure(figsize=(10, 6))
plt.plot(sorted_n_values, sorted_width_values, marker='o', linestyle='-')
plt.xlabel('Edge')
plt.ylabel('Bags')
plt.grid(True)
plt.show()
